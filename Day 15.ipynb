# %% [markdown]
# # Plotly And Cufflinks:-->

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.6.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100,4),columns = 'A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  1.487697 -0.978199 -0.602125  0.430632
# 1  0.920370 -1.190674 -0.630504  1.555317
# 2 -0.097947  1.361032 -0.127674 -2.340920
# 3  0.721403 -2.609103 -1.333070  0.369620
# 4  0.482583 -1.037957 -0.424858 -0.342004

# %%
df2 = pd.DataFrame({"Category":['A','B','C'],"Values":[32,44,67]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      44
# 2        C      67

# %%
df.head()
# Out:
#           A         B         C         D
# 0  1.487697 -0.978199 -0.602125  0.430632
# 1  0.920370 -1.190674 -0.630504  1.555317
# 2 -0.097947  1.361032 -0.127674 -2.340920
# 3  0.721403 -2.609103 -1.333070  0.369620
# 4  0.482583 -1.037957 -0.424858 -0.342004

# %%
df.iplot();
# This is going to make an intreactive plots using plotly
# Out:
# <div>                            <div id="78010ba4-c9d0-4eb2-9a17-d14ff6cf3c05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Scatter plots
df.iplot(kind='scatter',x='A',y='B',color ='yellow',mode='markers',size=20)
# Out:
# <div>                            <div id="0db79d16-6e53-407d-b505-2d1ea0c8d54c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
 # Bar plots
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>                            <div id="832a01f4-e202-4a63-97de-4b9fba1d61ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Note: We can use aggrigate functions on these plots using pandas

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="60faee93-bf91-47f3-9da5-ad2345900d5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="2a1d0d05-1ca4-4a75-89dc-c4cc86a7c8ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Now we are going to plot 3d graphs

# %%
# 1.3D surface plot

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,40,10],'z':[1,2,3,4,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  1
# 1  2  20  2
# 2  3  30  3
# 3  4  40  4
# 4  5  10  1

# %%
df3.iplot(kind='surface')
# Out:
# <div>                            <div id="0ce32cc7-6ac6-42df-b113-9dba014c282a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# We can learn some methods on 3d plotting
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="28363e19-4598-431c-bdd4-b22bf6e8fe71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Now We will see some more plots
# Histogram

# %%
df['A'].iplot(kind='hist',bins=50)
# Out:
# <div>                            <div id="860130c2-7e4d-4710-8aed-6c89da630c05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#We can pass multiple columns and off/on according to our need

# %%
df.iplot(kind ='hist')
# Out:
# <div>                            <div id="dd9bef17-3923-4b75-8900-c34b2ce13f9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Now we will see spread plots--> Very very important(😎 Stock Treading😎)

# %%
df[['A','B']].iplot(kind='spread')
# Now we will see spread
# Out:
# C:\Users\reliance\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#
# C:\Users\reliance\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
# <div>                            <div id="454cc4ef-d37f-4d56-8f8b-e839e510782d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# In this plot size of the bubble is depend on column 'C'
# Out:
# <div>                            <div id="f5cc6c68-a628-4375-9993-442aebfe0656" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#            A         B         C         D
# 0   1.487697 -0.978199 -0.602125  0.430632
# 1   0.920370 -1.190674 -0.630504  1.555317
# 2  -0.097947  1.361032 -0.127674 -2.340920
# 3   0.721403 -2.609103 -1.333070  0.369620
# 4   0.482583 -1.037957 -0.424858 -0.342004
# ..       ...       ...       ...       ...
# 95  0.330727 -0.804295  0.608848 -1.452000
# 96  0.854069  1.629326  2.294941 -0.876366
# 97  0.244597  0.626258  0.652228 -0.717375
# 98 -0.349416  0.882621 -0.173671 -0.518313
# 99 -1.202825  0.524622 -0.891563  0.109011
#
# [100 rows x 4 columns]

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="3555a020-b408-49ef-a61e-68b85b242a69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
