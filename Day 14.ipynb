# %% [markdown]
# # Pandas Bulit In - Data Visualzation

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(100)

# %%
df1 = pd.DataFrame(np.random.randn(20,4),np.arange(20),['A','B','C','D'])

# %%
df1.to_csv('df1.csv',index=False)

# %%
df1 = pd.read_csv('df1')

# %%
df1
# Out:
#           A         B         C         D
# 0  1.618982  1.541605 -0.251879 -0.842436
# 1  0.184519  0.937082  0.731000  1.361556
# 2 -0.326238  0.055676  0.222400 -1.443217
# 3 -0.756352  0.816454  0.750445 -0.455947
# 4  1.189622 -1.690617 -1.356399 -1.232435

# %%
# Now There are so many built in data visualization methods in pandas

# %%
df1['A'].hist(bins=20);

# %%
# If we import seaborn

# %%
import seaborn as sns

# %%
df1['A'].hist(bins=20);

# %%
# Methods for creating graphs using pandas

# %%
# 1st Method
df1['A'].plot(kind='hist',bins=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 2nd method
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2 = pd.DataFrame(np.random.randint(50,100,20).reshape(5,4),[1,2,3,4,5],['P','Q','R','S'])

# %%
df2
# Out:
#     P   Q   R   S
# 1  59  90  78  52
# 2  66  55  76  84
# 3  53  80  64  63
# 4  70  51  64  83
# 5  70  90  74  79

# %%
df2.plot.area(alpha=0.4);

# %%
df2.plot.bar();

# %%
df1.plot.scatter(x=['A'],y=['C']);

# %%
# we can seperate the data using colors

# %%
df1.plot.scatter(x=['A'],y=['B'],c='C');

# %%
df1.plot.box();

# %%
df3 = pd.DataFrame(np.random.randn(100,2),columns = ['a','b'])
df3.head()
# Out:
#           a         b
# 0 -0.578826 -1.199451
# 1 -1.705952  0.369164
# 2  1.876573 -0.376903
# 3  1.831936  0.003017
# 4 -0.076023  0.003958

# %%
df3.plot.hexbin(x='a',y='b',gridsize=10,cmap='coolwarm');

# %%
df1.plot.kde();
